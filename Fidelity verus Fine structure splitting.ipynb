# %% [markdown]
# <script type="text/javascript">
#     on = "View input";
#     off = "Hide input"
#     function onoff(){
#       currentvalue = document.getElementById('onoff').value;
#       if(currentvalue == off){
#         document.getElementById("onoff").value=on;
#           $('div.input').hide();
#       }else{
#         document.getElementById("onoff").value=off;
#           $('div.input').show();
#       }
# }
# </script>
# <input type="button" class="ui-button ui-widget ui-state-default ui-corner-all ui-button-text-only" value="Hide input" id="onoff" onclick="onoff();">
# <script>
#     onoff()
# </script>

# %% [markdown]
# # Fidelity versus Fine Structure splitting.

# %%
# %pylab inline
from mpl_toolkits.axes_grid1 import AxesGrid
from Icarus.Classes.QuantumDot import QuantumDot
from constants import Constants
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
constants = Constants()
qd = QuantumDot(constants.xtau, constants.xxtau, constants.ptau, constants.FSS, constants.crosstau)

# %% [markdown]
# ## No decoherence.

# %%
qd.crosstau = 0.
fss = np.linspace(-10, 10, 500)*1e-6
fidelities = [qd.ideal_fidelity_lorentzian(f)[0] for f in fss]
ghv = qd.ideal_fidelity_lorentzian(f)[1]

numerical_data_no_dec = np.loadtxt('out/fidelity_vs_fss/xtau1/fss_v_fidelity.txt', delimiter = ',')

plt.figure(figsize = (16./1.5,9./1.5))
plt.plot(numerical_data_no_dec[:,0], numerical_data_no_dec[:,1], 'r-', fss/1e-6, fidelities, 'b--')
plt.legend(['Monte carlo', 'Theoretical']) 
plt.text(6, 0.9, ' coherence ' + np.array(ghv).astype('|S3').tostring())
plt.xlim([-10, 10]) ; plt.ylim([0.45, 1.05])
plt.xticks(np.linspace(-10, 10, 11))
plt.xlabel('Fine structure splitting $eV$') ; plt.ylabel('Fidelity')

# %% [markdown]
# ## Decoherence time of 2.5 ns, coherence of 71%.

# %%
qd.crosstau = 2.5
fss = np.linspace(-10, 10, 500)*1e-6
fidelities = [qd.ideal_fidelity_lorentzian(f)[0] for f in fss]
ghv = qd.ideal_fidelity_lorentzian(f)[1]

numerical_data_with_dec = np.loadtxt('out/fidelity_vs_fss/cross_dephasing2.5ns/fss_v_fidelity.txt', delimiter = ',')

plt.figure(figsize = (16./1.5,9./1.5))
plt.plot(numerical_data_with_dec[:,0], numerical_data_with_dec[:,1], 'r-', fss/1e-6, fidelities, 'b--')
plt.legend(['Monte carlo', 'Theoretical']) 
plt.text(6, 0.9, ' coherence ' + np.array(ghv).astype('|S4').tostring())
plt.xlim([-10, 10]) ; plt.ylim([0.45, 1.05])
plt.xticks(np.linspace(-10, 10, 11))
plt.xlabel('Fine structure splitting $eV$') ; plt.ylabel('Fidelity')

# %% [markdown]
# ## Polariation resolved corrolation curves with and without decoherence.

# %%
def plot_corrs(arr11, arr12, arr21, arr22, arr31, arr32, title):
    delay = 180 - 20
    x_min = - 100
    x_max = 100
    
    fig = plt.figure(1, (12, 5))
    fig.subplots_adjust(left=0.05, right=0.98)
    
    fig.suptitle(title)
    
    grid = AxesGrid(fig, 111, nrows_ncols = (1, 3), axes_pad = 0.3, label_mode = "l")
    
    grid[0].plot(arr11[:,0]  - delay, arr11[:,1], 'b-', arr12[:,0] - delay, arr12[:,1], 'r-')
    grid[0].set_xlim([x_min, x_max]) ; grid[0].set_ylim([0, 2000])
    grid[0].set_yticks([]) ; grid[0].set_ylabel('Counts', fontsize = 14) ; grid[0].set_xlabel('$\\tau(ns)$', fontsize=14)
    grid[0].legend(['HH', 'HV'])
    
    grid[1].plot(arr21[:,0]  - delay, arr21[:,1], 'b-', arr22[:,0] - delay, arr22[:,1], 'r-')
    grid[1].set_xlim([x_min, x_max]) ; grid[1].set_ylim([0, arr21[:,1].max() + 10])
    grid[1].set_yticks([]) ; grid[1].set_xlabel('$\\tau(ns)$', fontsize=14)
    grid[1].legend(['DA', 'DD'])
    
    grid[2].plot(arr31[:,0]  - delay, arr31[:,1], 'b-', arr32[:,0] - delay, arr32[:,1], 'r-')
    grid[2].set_xlim([x_min, x_max]) ; grid[2].set_ylim([0, 200])
    grid[2].set_yticks([]) ; grid[2].set_xlabel('$\\tau(ns)$', fontsize=14)
    grid[2].legend(['LL', 'LR'])

# %% [markdown]
# ### With no fine structure splitting.

# %%
hh_no_dec_no_fss = np.loadtxt('out/fidelity_vs_fss/xtau1/fss-0.0 xtau-1/linearD1D3.txt', delimiter=',')
hv_no_dec_no_fss = np.loadtxt('out/fidelity_vs_fss/xtau1/fss-0.0 xtau-1/linearD1D4.txt', delimiter=',')

dd_no_dec_no_fss = np.loadtxt('out/fidelity_vs_fss/xtau1/fss-0.0 xtau-1/diagD1D3.txt', delimiter=',')
da_no_dec_no_fss = np.loadtxt('out/fidelity_vs_fss/xtau1/fss-0.0 xtau-1/diagD1D4.txt', delimiter=',')

ll_no_dec_no_fss = np.loadtxt('out/fidelity_vs_fss/xtau1/fss-0.0 xtau-1/circD1D3.txt', delimiter=',')
lr_no_dec_no_fss = np.loadtxt('out/fidelity_vs_fss/xtau1/fss-0.0 xtau-1/circD1D4.txt', delimiter=',')

hh_yes_dec_no_fss = np.loadtxt('out/fidelity_vs_fss/cross_dephasing2.5ns/fss-0.0 xtau-1.0/linear D1D3.txt', delimiter=',')
hv_yes_dec_no_fss = np.loadtxt('out/fidelity_vs_fss/cross_dephasing2.5ns/fss-0.0 xtau-1.0/linear D1D4.txt', delimiter=',')

dd_yes_dec_no_fss = np.loadtxt('out/fidelity_vs_fss/cross_dephasing2.5ns/fss-0.0 xtau-1.0/diag D1D3.txt', delimiter=',')
da_yes_dec_no_fss = np.loadtxt('out/fidelity_vs_fss/cross_dephasing2.5ns/fss-0.0 xtau-1.0/diag D1D4.txt', delimiter=',')

ll_yes_dec_no_fss = np.loadtxt('out/fidelity_vs_fss/cross_dephasing2.5ns/fss-0.0 xtau-1.0/circ D1D3.txt', delimiter=',')
lr_yes_dec_no_fss = np.loadtxt('out/fidelity_vs_fss/cross_dephasing2.5ns/fss-0.0 xtau-1.0/circ D1D4.txt', delimiter=',')

# %% [markdown]
# #### No decoherence

# %%
idx_fidelity = np.abs(np.array(numerical_data_no_dec[:,0] - 0)).argmin()
fidelity_no_dec = np.array(numerical_data_no_dec[idx_fidelity, 1]).astype('|S3').tostring()

plot_corrs(hh_no_dec_no_fss, hv_no_dec_no_fss, dd_no_dec_no_fss, da_no_dec_no_fss, ll_no_dec_no_fss, lr_no_dec_no_fss, 'No decoherence, fidelity: ' + fidelity_no_dec)

# %% [markdown]
# #### With decoherence

# %%
idx_fidelity = np.abs(np.array(numerical_data_with_dec[:,0] - 0)).argmin()
fidelity_with_dec = np.array(numerical_data_with_dec[idx_fidelity, 1]).astype('|S3').tostring()

plot_corrs( hh_yes_dec_no_fss, hv_yes_dec_no_fss, dd_yes_dec_no_fss, da_yes_dec_no_fss, ll_yes_dec_no_fss, lr_yes_dec_no_fss, 'with 0.21 decoherence, fidelity: ' + fidelity_with_dec)

# %% [markdown]
# ### With 2.75 $\\mu eV$ fine structure splitting.

# %%
hh_no_dec_yes_fss = np.loadtxt('out/fidelity_vs_fss/xtau1/fss--2.75 xtau-1/linear D1D3.txt', delimiter=',')
hv_no_dec_yes_fss = np.loadtxt('out/fidelity_vs_fss/xtau1/fss--2.75 xtau-1/linear D1D4.txt', delimiter=',')

dd_no_dec_yes_fss = np.loadtxt('out/fidelity_vs_fss/xtau1/fss--2.75 xtau-1/diag D1D3.txt', delimiter=',')
da_no_dec_yes_fss = np.loadtxt('out/fidelity_vs_fss/xtau1/fss--2.75 xtau-1/diag D1D4.txt', delimiter=',')

ll_no_dec_yes_fss = np.loadtxt('out/fidelity_vs_fss/xtau1/fss--2.75 xtau-1/circ D1D3.txt', delimiter=',')
lr_no_dec_yes_fss = np.loadtxt('out/fidelity_vs_fss/xtau1/fss--2.75 xtau-1/circ D1D4.txt', delimiter=',')

hh_yes_dec_yes_fss = np.loadtxt('out/fidelity_vs_fss/cross_dephasing2.5ns/fss--2.75 xtau-1.0/linear D1D3.txt', delimiter=',')
hv_yes_dec_yes_fss = np.loadtxt('out/fidelity_vs_fss/cross_dephasing2.5ns/fss--2.75 xtau-1.0/linear D1D4.txt', delimiter=',')

dd_yes_dec_yes_fss = np.loadtxt('out/fidelity_vs_fss/cross_dephasing2.5ns/fss--2.75 xtau-1.0/diag D1D3.txt', delimiter=',')
da_yes_dec_yes_fss = np.loadtxt('out/fidelity_vs_fss/cross_dephasing2.5ns/fss--2.75 xtau-1.0/diag D1D4.txt', delimiter=',')

ll_yes_dec_yes_fss = np.loadtxt('out/fidelity_vs_fss/cross_dephasing2.5ns/fss--2.75 xtau-1.0/circ D1D3.txt', delimiter=',')
lr_yes_dec_yes_fss = np.loadtxt('out/fidelity_vs_fss/cross_dephasing2.5ns/fss--2.75 xtau-1.0/circ D1D4.txt', delimiter=',')

# %% [markdown]
# #### No decoherence

# %%
idx_fidelity = np.abs(np.array(numerical_data_no_dec[:,0] - 2.75)).argmin()
fidelity_no_dec = np.array(numerical_data_no_dec[idx_fidelity, 1]).astype('|S3').tostring()

plot_corrs(hh_no_dec_yes_fss, hv_no_dec_yes_fss, dd_no_dec_yes_fss, da_no_dec_yes_fss, ll_no_dec_yes_fss, lr_no_dec_yes_fss, 'No decoherence, fss : 2.75 $\\mu eV$, fidelity: ' + fidelity_no_dec)

# %% [markdown]
# #### With decoherence

# %%
idx_fidelity = np.abs(np.array(numerical_data_with_dec[:,0] - 2.75)).argmin()
fidelity_with_dec = np.array(numerical_data_with_dec[idx_fidelity, 1]).astype('|S3').tostring()

plot_corrs(hh_yes_dec_yes_fss, hv_yes_dec_yes_fss, dd_yes_dec_yes_fss, da_yes_dec_yes_fss, ll_yes_dec_yes_fss, lr_yes_dec_yes_fss, 'With 0.21 decoherence, fss : 2.75 $\\mu eV$, fidelity: ' + fidelity_with_dec)
