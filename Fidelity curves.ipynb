# %% [markdown]
# <script type="text/javascript">
#     on = "View input";
#     off = "Hide input"
#     function onoff(){
#       currentvalue = document.getElementById('onoff').value;
#       if(currentvalue == off){
#         document.getElementById("onoff").value=on;
#           $('div.input').hide();
#       }else{
#         document.getElementById("onoff").value=off;
#           $('div.input').show();
#       }
# }
# </script>
# <input type="button" class="ui-button ui-widget ui-state-default ui-corner-all ui-button-text-only" value="Hide input" id="onoff" onclick="onoff();">
#
# _(You should click this button, you dont need to see the code)._

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
from Experiments.utils.plot_fidelity_curves import *
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# # Fidelity curves.

# %% [markdown]
# ### No FSS, no dephasing, no secondary emission.

# %%
plot_by_folder('gup45')

# %% [markdown]
# ### 50 $\mu eV$ FSS, no dephasing, no secondary emission.

# %%
plot_by_folder('yqfrc')

# %% [markdown]
# ### 1. $\mu eV$ FSS, no dephasing, no secondary emission.

# %%
plot_by_folder('8cl1x')

# %% [markdown]
# ### 1. $\mu eV$ FSS, 2.5 $ns$ dephasing, no secondary emission.

# %%
plot_by_folder('19h4i')

# %% [markdown]
# ### 1. $\mu eV$ FSS, No dephasing, 0.18 secondary emission.

# %%
plot_by_folder('fups3')

# %% [markdown]
# ### 1. $\mu eV$ FSS, 2.5 $ns$ dephasing, 0.18 secondary emission.

# %%
plot_by_folder('3x73m')

# %%
run Experiments/g2_vs_power.py
# Out:
# Running g2 vs power.
# Iteration: 2 of 10.
# Iteration: 3 of 10.
# Iteration: 4 of 10.
# Iteration: 5 of 10.
# Iteration: 6 of 10.
# Iteration: 7 of 10.
# Iteration: 8 of 10.
# Iteration: 9 of 10.
# Iteration: 10 of 10.

# %% [markdown]
# ### No FSS, no dephasing, no secondary emission, background emission rate 0.05.

# %%
plot_by_folder('9ozpbplot')

# %% [markdown]
# ### No FSS, no dephasing, 0.2 secondary emission, background emission rate 0.05, detector eff of 0.5

# %%
plot_by_folder('99ug3')
