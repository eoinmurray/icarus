# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
run test/QuantumDotTest.py

# %%
run Experiments/fidelity.py
# Out:
# Starting fidelity measurement with fss:  0.0 ueV and xlifetime of  1.0 ns
# Expecting fidelity of  0.86
# First order coherence  0.71
# Running from main, starting multiprocessing.
# Degrees of corrolation.
# 	linear:    1.0
# 	diagonal:  0.78460326836
# 	circular:  -0.771493642057
# fidelity:  0.89
# real/expected:  103.719493221 %
