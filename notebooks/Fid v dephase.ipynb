# %%
# %pylab inline
from fid_v_dephase_helpers import *
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# # Degrees of corrolation in rectilinear, diagonal and circular basis versus cross dephasing lifetime.
# No fine structure, no secondary emission, no background emission, no spin scattering.

# %%
rootdir = '../out/2013-08-03/crosstau/'
dat = get_data(rootdir, 'crosstau')
plot_deg_of_corr(dat)

# %%
hold_param = dat[0]
grect = dat[1][0]
gdiag = dat[1][1]
gcirc = dat[1][2]
plt.plot(hold_param, gdiag/ grect)
plt.plot(hold_param, - gcirc/ grect)

# %%
rootdir = '../out/2013-08-02/fidelity_vs_fss/'
dat = get_data(rootdir, 'crosstau')
plot_deg_of_corr(dat)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-02bef3849df0> in <module>()
#       1 rootdir = '../out/2013-08-02/fidelity_vs_fss/'
# ----> 2 dat = get_data(rootdir, 'crosstau')
#       3 plot_deg_of_corr(dat)
#
# /Users/eoinmurray/Documents/tyndall/icarus/notebooks/fid_v_dephase_helpers.py in get_data(rootdir, param_name)
#      81
#      82         if os.path.exists(outfileName):
# ---> 83             params = np.genfromtxt(outfileName, dtype=str, delimiter=',')
#      84             crosstau = float(params[:,1][params[:,0]==param_name][0])
#      85
#
# //anaconda/lib/python2.7/site-packages/numpy/lib/npyio.pyc in genfromtxt(fname, dtype, comments, delimiter, skiprows, skip_header, skip_footer, converters, missing, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise)
#    1636             # Raise an exception ?
#    1637             if invalid_raise:
# -> 1638                 raise ValueError(errmsg)
#    1639             # Issue a warning ?
#    1640             else:
#
# ValueError: Some errors were detected !
#     Line #3 (got 2 columns instead of 1)
